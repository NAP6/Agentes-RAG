# %%
import os
import pandas as pd


def leer_y_combinar_csv(directorio):
    archivos_csv = [archivo for archivo in os.listdir(directorio) if archivo.endswith('.csv')]
    dataframes = [pd.read_csv(os.path.join(directorio, archivo), index_col=0) for archivo in archivos_csv]
    df_combinado = pd.concat(dataframes, ignore_index=True)
    return df_combinado


# Uso de ejemplo
directorio = './data/raw'
df_raw = leer_y_combinar_csv(directorio)
df_raw
# Out:
#                   type                        element_id  \
# 0    UncategorizedText  2a79c74e7aacdeced6760e8e3a21a60e
# 1               Header  6afcf8d92b2e1513a713972102cd8216
# 2    UncategorizedText  3a8065e6efc332ca5cd4bf6950df8663
# 3                Title  683c711fcc9f2170bd2584bb150a2725
# 4        NarrativeText  5549ff0886ea40db28c2e81555d860fb
# ..                 ...                               ...
# 219              Title  8cc9db04a2f4cc220f257af592fffe8a
# 220      NarrativeText  2468b5236da66343df583c9d870c41f3
# 221              Title  7f10efb85a3fe1e47acc1d058e6c9591
# 222      NarrativeText  a3a2969e742677c71e137666dcca51ba
# 223             Header  80299957d63e5473aca4b1f6529f8263
#
#                                                   text  \
# 0                                              1 2 0 2
# 1                              r p A 2 1 ] L C . s c [
# 2                  4 v 1 0 4 1 1 . 5 0 0 2 : v i X r a
# 3    Retrieval-Augmented Generation for Knowledge-I...
# 4                       Patrick Lewis'?, Ethan Perez*,
# ..                                                 ...
# 219                               H Retrieval Collapse
# 220  In preliminary experiments, we observed that f...
# 221                  I Number of instances per dataset
# 222  The number of training, development and test d...
# 223                                                 19
#
#                                     coordinates_points coordinates_system  \
# 0    ((45.388888888888886, 589.6111111111111), (45....         PixelSpace
# 1    ((45.1381721496582, 688.5795288085938), (45.13...         PixelSpace
# 2    ((45.388888888888886, 1094.1666666666665), (45...         PixelSpace
# 3    ((463.0325927734375, 276.19338500000003), (463...         PixelSpace
# 4    ((664.65380859375, 498.6003255555554), (664.65...         PixelSpace
# ..                                                 ...                ...
# 219  ((297.9806823730469, 892.2873244444444), (297....         PixelSpace
# 220  ((299.0027777777778, 961.0620044444444), (299....         PixelSpace
# 221  ((298.6259765625, 1217.178991111111), (298.625...         PixelSpace
# 222  ((299.14166666666665, 1285.9536711111111), (29...         PixelSpace
# 223  ((836.1638888888889, 2061.325893333333), (836....         PixelSpace
#
#      coordinates_layout_width  coordinates_layout_height        last_modified  \
# 0                        1700                       2200  2024-08-18T17:06:27
# 1                        1700                       2200  2024-08-18T17:06:27
# 2                        1700                       2200  2024-08-18T17:06:27
# 3                        1700                       2200  2024-08-18T17:06:27
# 4                        1700                       2200  2024-08-18T17:06:27
# ..                        ...                        ...                  ...
# 219                      1700                       2200  2024-08-18T17:06:27
# 220                      1700                       2200  2024-08-18T17:06:27
# 221                      1700                       2200  2024-08-18T17:06:27
# 222                      1700                       2200  2024-08-18T17:06:27
# 223                      1700                       2200  2024-08-18T17:06:27
#
#             filetype languages  page_number file_directory  \
# 0    application/pdf   ['eng']            1      ../papers
# 1    application/pdf   ['eng']            1      ../papers
# 2    application/pdf   ['eng']            1      ../papers
# 3    application/pdf   ['eng']            1      ../papers
# 4    application/pdf   ['eng']            1      ../papers
# ..               ...       ...          ...            ...
# 219  application/pdf   ['eng']           19      ../papers
# 220  application/pdf   ['eng']           19      ../papers
# 221  application/pdf   ['eng']           19      ../papers
# 222  application/pdf   ['eng']           19      ../papers
# 223  application/pdf   ['eng']           19      ../papers
#
#                                               filename  detection_class_prob  \
# 0    Retrieval-Augmented Generation for Knowledge-I...                   NaN
# 1    Retrieval-Augmented Generation for Knowledge-I...              0.515812
# 2    Retrieval-Augmented Generation for Knowledge-I...                   NaN
# 3    Retrieval-Augmented Generation for Knowledge-I...              0.479248
# 4    Retrieval-Augmented Generation for Knowledge-I...              0.432448
# ..                                                 ...                   ...
# 219  Retrieval-Augmented Generation for Knowledge-I...              0.907250
# 220  Retrieval-Augmented Generation for Knowledge-I...              0.947708
# 221  Retrieval-Augmented Generation for Knowledge-I...              0.911698
# 222  Retrieval-Augmented Generation for Knowledge-I...              0.881191
# 223  Retrieval-Augmented Generation for Knowledge-I...              0.622305
#
#                             parent_id image_path
# 0                                 NaN        NaN
# 1                                 NaN        NaN
# 2    6afcf8d92b2e1513a713972102cd8216        NaN
# 3    6afcf8d92b2e1513a713972102cd8216        NaN
# 4    683c711fcc9f2170bd2584bb150a2725        NaN
# ..                                ...        ...
# 219                               NaN        NaN
# 220  8cc9db04a2f4cc220f257af592fffe8a        NaN
# 221                               NaN        NaN
# 222  7f10efb85a3fe1e47acc1d058e6c9591        NaN
# 223                               NaN        NaN
#
# [224 rows x 16 columns]

# %%
df_raw.columns
# Out:
# Index(['type', 'element_id', 'text', 'coordinates_points',
#        'coordinates_system', 'coordinates_layout_width',
#        'coordinates_layout_height', 'last_modified', 'filetype', 'languages',
#        'page_number', 'file_directory', 'filename', 'detection_class_prob',
#        'parent_id', 'image_path'],
#       dtype='object')

# %%
# Eliminar la columna coordinates_points, coordinates_system
df_raw = df_raw.drop(columns=['coordinates_system', 'coordinates_layout_width',
                              'coordinates_layout_height', 'last_modified', 'file_directory',])

# %%
df_raw
# Out:
#                   type                        element_id  \
# 0    UncategorizedText  2a79c74e7aacdeced6760e8e3a21a60e
# 1               Header  6afcf8d92b2e1513a713972102cd8216
# 2    UncategorizedText  3a8065e6efc332ca5cd4bf6950df8663
# 3                Title  683c711fcc9f2170bd2584bb150a2725
# 4        NarrativeText  5549ff0886ea40db28c2e81555d860fb
# ..                 ...                               ...
# 219              Title  8cc9db04a2f4cc220f257af592fffe8a
# 220      NarrativeText  2468b5236da66343df583c9d870c41f3
# 221              Title  7f10efb85a3fe1e47acc1d058e6c9591
# 222      NarrativeText  a3a2969e742677c71e137666dcca51ba
# 223             Header  80299957d63e5473aca4b1f6529f8263
#
#                                                   text  \
# 0                                              1 2 0 2
# 1                              r p A 2 1 ] L C . s c [
# 2                  4 v 1 0 4 1 1 . 5 0 0 2 : v i X r a
# 3    Retrieval-Augmented Generation for Knowledge-I...
# 4                       Patrick Lewis'?, Ethan Perez*,
# ..                                                 ...
# 219                               H Retrieval Collapse
# 220  In preliminary experiments, we observed that f...
# 221                  I Number of instances per dataset
# 222  The number of training, development and test d...
# 223                                                 19
#
#                                     coordinates_points         filetype  \
# 0    ((45.388888888888886, 589.6111111111111), (45....  application/pdf
# 1    ((45.1381721496582, 688.5795288085938), (45.13...  application/pdf
# 2    ((45.388888888888886, 1094.1666666666665), (45...  application/pdf
# 3    ((463.0325927734375, 276.19338500000003), (463...  application/pdf
# 4    ((664.65380859375, 498.6003255555554), (664.65...  application/pdf
# ..                                                 ...              ...
# 219  ((297.9806823730469, 892.2873244444444), (297....  application/pdf
# 220  ((299.0027777777778, 961.0620044444444), (299....  application/pdf
# 221  ((298.6259765625, 1217.178991111111), (298.625...  application/pdf
# 222  ((299.14166666666665, 1285.9536711111111), (29...  application/pdf
# 223  ((836.1638888888889, 2061.325893333333), (836....  application/pdf
#
#     languages  page_number                                           filename  \
# 0     ['eng']            1  Retrieval-Augmented Generation for Knowledge-I...
# 1     ['eng']            1  Retrieval-Augmented Generation for Knowledge-I...
# 2     ['eng']            1  Retrieval-Augmented Generation for Knowledge-I...
# 3     ['eng']            1  Retrieval-Augmented Generation for Knowledge-I...
# 4     ['eng']            1  Retrieval-Augmented Generation for Knowledge-I...
# ..        ...          ...                                                ...
# 219   ['eng']           19  Retrieval-Augmented Generation for Knowledge-I...
# 220   ['eng']           19  Retrieval-Augmented Generation for Knowledge-I...
# 221   ['eng']           19  Retrieval-Augmented Generation for Knowledge-I...
# 222   ['eng']           19  Retrieval-Augmented Generation for Knowledge-I...
# 223   ['eng']           19  Retrieval-Augmented Generation for Knowledge-I...
#
#      detection_class_prob                         parent_id image_path
# 0                     NaN                               NaN        NaN
# 1                0.515812                               NaN        NaN
# 2                     NaN  6afcf8d92b2e1513a713972102cd8216        NaN
# 3                0.479248  6afcf8d92b2e1513a713972102cd8216        NaN
# 4                0.432448  683c711fcc9f2170bd2584bb150a2725        NaN
# ..                    ...                               ...        ...
# 219              0.907250                               NaN        NaN
# 220              0.947708  8cc9db04a2f4cc220f257af592fffe8a        NaN
# 221              0.911698                               NaN        NaN
# 222              0.881191  7f10efb85a3fe1e47acc1d058e6c9591        NaN
# 223              0.622305                               NaN        NaN
#
# [224 rows x 11 columns]

# %%
import ollama

def describe_img(img_path):
    query = "Describe in comprehensive detail the contents of the image, focusing intensely on what it represents, its functions, and what it shows. Elaborate on the specific elements, their configurations, and how they contribute to the overall meaning or purpose of the image within the context of a scientific paper. Emphasize the significance of any notable features, colors, or patterns, explaining their relevance in understanding the figure. Ensure the description is thorough, avoiding personal references, and strictly maintain an objective tone by stating facts such as 'the image includes...' or 'the figure demonstrates...'"
    
    response = ollama.generate(
        model='llava-llama3',
        prompt=query,
        images=[img_path]
    )
    return response['response']

# %%
def generate_markdown_tables(img_path):
    query = """
    Transform the tables visible in the image into Markdown table format. 
    Do not include any descriptive text, only provide the tables in Markdown format.
    """

    response = ollama.generate(
        model='llava-llama3',
        prompt=query,
        images=[img_path]
    )
    return response['response']

# %%
print(describe_img('./images/Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks.pdf/figure-2-1.jpg'))
# Out:
# The image presents a detailed diagram that illustrates the process of gene expression through the use of different colors to distinguish between various components. The diagram is composed of multiple rectangles and arrows, each serving a specific purpose in explaining the concept.
#
# At the center of the diagram, there's an open book titled "Epigenetic End-Game through end-Pa cificity". This suggests that the diagram might be related to epigenetics, which is a branch of genetics that studies heritable changes in gene function that occur without a change in the underlying DNA sequence.
#
# The diagram also includes a legend that explains the color-coding scheme used throughout. The legend lists three colors: green, blue, and purple. These colors are presumably assigned to different parts of the diagram, each representing a specific aspect of the process.
#
# Several arrows connect these rectangles, indicating the flow of information or actions between them. This could represent the sequence of events that take place during the gene expression process. For instance, one arrow might indicate the direction of DNA replication, another might show the progression from the transcription to translation phase of protein synthesis.
#
# Overall, the diagram serves as a visual aid to explain a complex scientific concept in an accessible and understandable manner. It uses color-coding and directional arrows to guide the viewer through the process of gene expression, making it easier to understand the various components involved and how they interact with each other.

# %%
print(generate_markdown_tables('./images/Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks.pdf/table-6-1.jpg'))
# Out:
# | Model | RAC 1 (R J) LTL | RAC 2 (R J) LTL | EV3 (E V) LTL |
# | --- | --- | --- | --- |
# | Book | 14-19-90 &gt; 26.6% | 14-19-90 &gt; 26.6% | 14-19-90 &gt; 42.4% |
# | RAC Sce | 5/22 | 11/16 | 0/22 |
# | EV3 (E V) LTL | 21-23 | 34.2% &gt; R J | 21-23 |

# %% [markdown]
# | Model | RAC 1 (R J) LTL | RAC 2 (R J) LTL | EV3 (E V) LTL |
# | --- | --- | --- | --- |
# | Book | 14-19-90 &gt; 26.6% | 14-19-90 &gt; 26.6% | 14-19-90 &gt; 42.4% |
# | RAC Sce | 5/22 | 11/16 | 0/22 |
# | EV3 (E V) LTL | 21-23 | 34.2% &gt; R J | 21-23 |
